# %%
# !yolo task=detect mode=predict model=/Users/elman/Documents/GITHUB_DEEP_LEARNING/AI_CC_Competition/best.pt source=/Users/elman/Downloads/AIC23_Track4_Automated_Checkout/testA/testA_1.mp4 show=True save=True
# Out:
# Ultralytics YOLOv8.0.52 🚀 Python-3.9.13 torch-1.13.1 CPU
# Model summary (fused): 168 layers, 3509060 parameters, 0 gradients, 10.4 GFLOPs
#
# video 1/1 (1/1799) /Users/elman/Downloads/AIC23_Track4_Automated_Checkout/testA/testA_1.mp4: 384x640 1 All Free and Clear Pods, 1 Downy Odor Defense, 174.5ms
# video 1/1 (2/1799) /Users/elman/Downloads/AIC23_Track4_Automated_Checkout/testA/testA_1.mp4: 384x640 1 All Free and Clear Pods, 176.4ms
# video 1/1 (3/1799) /Users/elman/Downloads/AIC23_Track4_Automated_Checkout/testA/testA_1.mp4: 384x640 (no detections), 195.3ms
# video 1/1 (4/1799) /Users/elman/Downloads/AIC23_Track4_Automated_Checkout/testA/testA_1.mp4: 384x640 1 All Free and Clear Pods, 214.1ms
# video 1/1 (5/1799) /Users/elman/Downloads/AIC23_Track4_Automated_Checkout/testA/testA_1.mp4: 384x640 1 All Free and Clear Pods, 1 Mochi Ice Cream, 175.0ms
# ...
